# %%
import pixiedust
pixiedust.optOut()
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.15</span>
#         </div>
# Pixiedust will not collect anonymous install statistics.

# %%
import pandas as pd
data_1 = pd.read_excel("../../Imigration_Data/Imigration_Enforsment_Actions_YRBK_2016_ENF_Excel_Final/fy2016_table33.xls")
data_1.head()
# Out:
#    Year  Number
# 0  1925   22199
# 1  1926   12735
# 2  1927   16393
# 3  1928   23566
# 4  1929   32711

# %%
# Let's start out by removing the ',' from our numbers in the Deaths and Population columns so that we can use them as integers
#df_data_2['Deaths'] = df_data_2['Deaths'].str.replace(',', '')
#df_data_2['Deaths'] = df_data_2['Deaths'].astype(int)
data_1['Year'] = data_1['Year'].astype(int)
data_1['Number'] = data_1['Number'].astype(int)

# %%
df_pixie_1 = pixiedust.sampleData("file:///home/vas1a/Projects/Imigration_Data/Imigration_Enforsment_Actions_YRBK_2016_ENF_Excel_Final/fy2016_table333.csv")
# Out:
# ...
# Downloaded 1114 bytes
# Creating pandas DataFrame for 'file:///home/vas1a/Projects/Imigration_Data/Imigration_Enforsment_Actions_YRBK_2016_ENF_Excel_Final/fy2016_table333.csv'. Please wait...
# Loading file using 'pandas'
# Successfully created pandas DataFrame for 'file:///home/vas1a/Projects/Imigration_Data/Imigration_Enforsment_Actions_YRBK_2016_ENF_Excel_Final/fy2016_table333.csv'

# %%
display(df_pixie_1)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>
#         <div class="pd_save is-viewer-good" style="padding-right:10px;text-align: center;line-height:initial !important;font-size: xx-large;font-weight: 500;color: coral;">
#
#         </div>
#     <div id="chartFigure1fbfbb40" class="pd_save is-viewer-good" style="overflow-x:auto">
#             <style type="text/css" class="pd_save">
#     .df-table-wrapper .panel-heading {
#       border-radius: 0;
#       padding: 0px;
#     }
#     .df-table-wrapper .panel-heading:hover {
#       border-color: #008571;
#     }
#     .df-table-wrapper .panel-title a {
#       background-color: #f9f9fb;
#       color: #333333;
#       display: block;
#       outline: none;
#       padding: 10px 15px;
#       text-decoration: none;
#     }
#     .df-table-wrapper .panel-title a:hover {
# ...

# %%
# data['Year'] = pd.eval(data['Year'])
data.Year = pd.to_numeric(data.Year, errors='coerce')
data.Number = pd.to_numeric(data.Number)
data.head()
# Out:
#      Year  Number
# 0  1925.0   22199
# 1  1926.0   12735
# 2  1927.0   16393
# 3  1928.0   23566
# 4  1929.0   32711

# %%
data34d_1 = pd.read_excel("../../Imigration_Data/Imigration_Enforsment_Actions_YRBK_2016_ENF_Excel_Final/fy2016_table34d.xls")
data34d_1.head()
# Out:
#   Region and country of nationality 2007 2008 1 2009 2 Y2010 2011 2012 2013  \
# 0                       Afghanistan   28     74     76    92  111   98   70
# 1                           Albania  259    362    331   321  258  277  423
# 2                           Algeria   49     59     53    62   36   42   27
# 3                            Angola   13     30     24    22   28   22   16
# 4               Antigua and Barbuda   23     69     59    57   47   56   40
#
#   2014 2015 2016 4
# 0   66   71       84
# 1  408   91      152
# 2   42   26       38
# 3   13   11        6
# 4   31   21       16

# %%
df34d = pixiedust.sampleData("file:///home/vas1a/Projects/Imigration_Data/Imigration_Enforsment_Actions_YRBK_2016_ENF_Excel_Final/fy2016_table34d1.csv")
# Out:
# Creating pandas DataFrame for 'file:///home/vas1a/Projects/Imigration_Data/Imigration_Enforsment_Actions_YRBK_2016_ENF_Excel_Final/fy2016_table34d1.csv'. Please wait...
# Loading file using 'pandas'
# Successfully created pandas DataFrame for 'file:///home/vas1a/Projects/Imigration_Data/Imigration_Enforsment_Actions_YRBK_2016_ENF_Excel_Final/fy2016_table34d1.csv'

# %%
df34d['2007'] = df34d['2007'].str.replace('D', '0')
df34d['2007'] = df34d['2007'].str.replace('-', '0')
df34d['2007'] = df34d['2007'].str.replace('X', '0')
df34d['2007'] = df34d['2007'].str.replace(',', '')
df34d['2007'] = df34d['2007'].astype(int)

# %%
df34d['2008'] = df34d['2008'].str.replace('D', '0')
df34d['2008'] = df34d['2008'].str.replace('-', '0')
df34d['2008'] = df34d['2008'].str.replace('X', '0')
df34d['2008'] = df34d['2008'].str.replace(',', '')
df34d['2008'] = df34d['2008'].astype(int)

# %%
display(df34d)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div>

# %%
df34d['2009'] = df34d['2009'].str.replace('D', '0')
df34d['2009'] = df34d['2009'].str.replace('-', '0')
df34d['2009'] = df34d['2009'].str.replace('X', '0')
df34d['2009'] = df34d['2009'].str.replace(',', '')
df34d['2009'] = df34d['2009'].astype(int)

# %%
df34d['2010'] = df34d['2010'].str.replace('D', '0').replace('-', '0').replace('X', '0').replace(',', '')
df34d['2010'] = df34d['2010'].astype(int)

# %%
df34d['2011'] = df34d['2011'].str.replace('D', '0').replace('-', '0').replace('X', '0').replace(',', '')
df34d['2011'] = df34d['2011'].astype(int)

df34d['2012'] = df34d['2012'].str.replace('D', '0').replace('-', '0').replace('X', '0').replace(',', '')
df34d['2012'] = df34d['2012'].astype(int)

df34d['2013'] = df34d['2013'].str.replace('D', '0').replace('-', '0').replace('X', '0').replace(',', '')
df34d['2013'] = df34d['2013'].astype(int)

df34d['2014'] = df34d['2014'].str.replace('D', '0').replace('-', '0').replace('X', '0').replace(',', '')
df34d['2014'] = df34d['2014'].astype(int)

df34d['2015'] = df34d['2015'].str.replace('D', '0').replace('-', '0').replace('X', '0').replace(',', '')
df34d['2015'] = df34d['2015'].astype(int)

df34d['2016'] = df34d['2016'].str.replace('D', '0').replace('-', '0').replace('X', '0').replace(',', '')
df34d['2016'] = df34d['2016'].astype(int)
